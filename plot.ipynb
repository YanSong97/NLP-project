# %% [markdown]
# <a href="https://colab.research.google.com/github/YanSong97/NLP-project/blob/master/plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Gigaword Rouge-L

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iteration_1 = np.arange(10000,21000,1000)
gr_ml = np.array([0.3940,0.4003,0.4050,0.4039,0.4055,0.4037,0.4063,0.4065,0.4078,0.4055,0.4092])
gr_ml_rl = np.array([0.3940,0.4051,0.4069,0.4077,0.4050,0.4054,0.4030,0.4058,0.4058,0.4064,0.4061])
gr_rl_r = np.array([0.3940,0.4209,0.4273,0.4247,0.4272,0.4288,0.4323,0.4333,0.4317,0.4335,0.4330])  

iteration_2 = np.append(np.append(np.array([10000]),np.arange(10500,11250,50)),(np.arange(11300,14600,100)))
gr_rl_b =  np.array([0.3940,0.3971,0.3957,0.3991,0.3987,0.3986,0.4001,0.3995,0.3991,0.3980,0.3977,0.3986,0.3976,0.3978,0.3996,0.3997,0.4012,0.4023,0.4009, 0.4035,0.4017,0.4011,0.4013,0.3996,0.4000,0.4006,0.4016,0.4006,0.4008,0.4005,0.4020,0.4005,0.4012,0.3995,0.4001,0.4005,0.3996,0.4004,0.4057,0.4027,0.4016,0.4011,0.4009,0.3987,0.4026,0.3998,0.4017,0.4024,0.4005])


plt.figure(figsize=(8,6))
plt.style.use('seaborn')
 
plt.plot(iteration_1, gr_ml, marker='d', linewidth=2, alpha=0.9, label='ML')
plt.plot(iteration_1, gr_ml_rl, marker='v',  linewidth=2, alpha=0.9, label='ML+RL(r)')
plt.plot(iteration_1, gr_rl_r, marker='s', linewidth=2, alpha=0.9, label='RL(r)')
plt.plot(iteration_2, gr_rl_b, marker='.', linewidth=2, alpha=0.9, label='RL(b)')

plt.legend(ncol=4,loc='lower right')
plt.title("Plot of Validation Rouge-L Score for Gigaword Dataset")
plt.xlabel("Training Iterations")
plt.ylabel("Rouge-L")
plt.show()

# %% [markdown]
# #### Gigaword BERTScore

# %%
iteration_1 = np.arange(10000,21000,1000)
gb_ml = np.array([0.9008,0.9017,0.9024,0.9026,0.9031,0.9026,0.9034,0.9031,0.9033,0.9032,0.9037])
gb_ml_rl = np.array([0.9008,0.9025,0.9028,0.9031,0.9027,0.9027,0.9025,0.9027,0.9028,0.9031,0.9030])
gb_rl_r = np.array([0.9008,0.8779,0.8704,0.8696,0.8695,0.8684026002883911,0.8672430515289307,0.8638581037521362,0.8657578229904175,0.8679165244102478,0.8665953874588013])  

iteration_2 = np.append(np.arange(10000,11250,50),(np.arange(11300,14600,100)))
gb_rl_b =  np.array([0.9008,0.9018734097480774,0.9020373821258545,0.9015077352523804,0.9016919136047363,0.9019822478294373,0.9022386074066162,0.902203381061554,  \
                  0.9021578431129456,0.9020208120346069,0.9019886255264282,0.9018607139587402,0.9018115401268005,0.9021751880645752,0.9023839235305786,  \
                  0.9026513695716858,0.9024652242660522,0.9023861885070801,0.9022435545921326,0.9026148915290833,0.9027001857757568,0.9027605056762695,  \
                  0.9024797081947327,0.9028233289718628,0.9030805230140686,0.9033142328262329,0.9030134081840515,0.9030899405479431,0.9038068652153015,  \
                  0.9033812880516052,0.9034574031829834,0.9033688902854919,0.903092026710510,0.9031205773353577,0.9032406210899353,0.903664231300354,  \
                  0.9035991430282593,0.9035979509353638,0.9036861062049866,0.9039427638053894,0.903577446937561,0.9037619233131409,0.9034201502799988,  \
                  0.9030752182006836,0.9034005999565125,0.9038577079772949,0.9036712050437927,0.9043444991111755,0.9039359092712402,0.9036781787872314,  \
                  0.9039506912231445,0.9038762450218201,0.9037942290306091,0.9043368697166443,0.9041448831558228,0.9038739204406738,0.9042147994041443,0.9038845300674438])


plt.figure(figsize=(8,6))
plt.style.use('seaborn')
 
plt.plot(iteration_1, gb_ml, marker='d', linewidth=2, alpha=0.9, label='ML')
plt.plot(iteration_1, gb_ml_rl, marker='v',  linewidth=2, alpha=0.9, label='ML+RL(r)')
plt.plot(iteration_1, gb_rl_r, marker='s', linewidth=2, alpha=0.9, label='RL(r)')
plt.plot(iteration_2, gb_rl_b, marker='.', linewidth=2, alpha=0.9, label='RL(b)')

plt.legend(ncol=4,loc='lower left')
plt.title("Plot of Validation BERTScore for Gigaword Dataset")
plt.xlabel("Training Iterations")
plt.ylabel("BERTScore")
plt.show()

# %% [markdown]
# #### giga bertscore vs rouge

# %%
plt.figure(figsize=(8,6))
plt.style.use('seaborn')
 
plt.scatter(gr_ml, gb_ml, marker='d', linewidth=2, alpha=0.9, label='ML')
plt.scatter(gr_ml_rl[1:], gb_ml_rl[1:], marker='v',  linewidth=2, alpha=0.9, label='ML+RL(r)')
plt.scatter(gr_rl_r[1:], gb_rl_r[1:], marker='s', linewidth=2, alpha=0.9, label='RL(r)')
plt.scatter(gr_rl_b[1:], gb_rl_b[10:], marker='.', linewidth=2, alpha=0.9, label='RL(b)')

plt.legend(ncol=4,loc='lower left')
plt.title("Plot of BERTScore against Rouge-L for Gigaword Dataset")
plt.xlabel("Rouge-L")
plt.ylabel("BERTScore")
plt.show()

# %% [markdown]
# #### cnn rouge

# %%
iteration_1 = np.arange(10000,21000,1000)
cr_ml = np.array([0.4023,0.4012,0.4042,0.4049,0.4000,0.4087,0.4025,0.4053,0.4054,0.4073,0.4048])
cr_ml_rl = np.array([0.4023,0.4068,0.4045,0.4050,0.4055,0.4047,0.4047,0.4058,0.4033,0.4053,0.4059])
cr_rl_r = np.array([0.4023,0.4010,0.4158,0.4349,0.4248,0.4371,0.4262,0.4264,0.4426,0.4340,0.4278])  

iteration_2 = np.arange(10000,12900,100)
cr_rl_b =  np.array([0.4023,0.4050,0.4083,0.4113,0.4102,0.4077,0.4068,0.4058,0.4080,0.4056,0.4152,0.4092,0.4069,0.4037,0.4107,0.4046,0.3969,0.3985,0.3906,0.4072,0.4074,0.4088,0.4042,0.4093,0.3999,0.4128,0.3963,0.4117,0.4060])


plt.figure(figsize=(8,6))
plt.style.use('seaborn')
 
plt.plot(iteration_1, cr_ml, marker='d', linewidth=2, alpha=0.9, label='ML')
plt.plot(iteration_1, cr_ml_rl, marker='v',  linewidth=2, alpha=0.9, label='ML+RL(r)')
plt.plot(iteration_1, cr_rl_r, marker='s', linewidth=2, alpha=0.9, label='RL(r)')
plt.plot(iteration_2, cr_rl_b, marker='.', linewidth=2, alpha=0.9, label='RL(b)')

plt.legend(ncol=4,loc='lower right')
plt.title("Plot of Validation Rouge-L Score for CNN/DailyMail Dataset")
plt.xlabel("Training Iterations")
plt.ylabel("Rouge-L")
plt.show()

# %% [markdown]
# #### cnn bertscore

# %%
iteration_1 = np.arange(10000,21000,1000)
cb_ml = np.array([0.8942917585372925,0.8949859738349915,0.8961774110794067,0.89398193359375,0.8936081528663635,0.8958911895751953,0.8949451446533203,0.8952271938323975,0.894915759563446,0.896696150302887,0.8959292769432068])
cb_ml_rl = np.array([0.8942917585372925,0.8946406245231628,0.8952872157096863,0.8949735760688782,0.8953328728675842,0.8954775929450989,0.89595627784729,0.8950275182723999,0.8953807950019836,0.8951349854469299,0.8957590460777283])
cb_rl_r = np.array([0.8942917585372925,0.8729562759399414,0.8759876489639282,0.8835082054138184,0.8752874135971069,0.8855898976325989,0.8638209700584412,0.8740276098251343,0.8839461803436279,0.8734917640686035,0.8631736040115356])  

iteration_2 = np.arange(10000,12900,100)
cb_rl_b =  np.array([0.8942917585372925,0.8934506177902222,0.8961038589477539,0.8965376019477844,0.8955327868461609,0.8957505822181702,0.8979785442352295,0.8987767696380615,0.8991556763648987,0.9007872939109802,0.9006882309913635,0.9006849527359009,0.9011027812957764,0.9007390141487122,0.9012660980224609,0.9021445512771606,0.901988685131073,0.9014483094215393,0.9013339877128601,0.902001142501831,0.9020184874534607,0.9022303819656372,0.9021865129470825,0.902517557144165,0.9023751020431519,0.9023810029029846,0.9023544788360596,0.9030739665031433,0.9025983214378357])


plt.figure(figsize=(8,6))
plt.style.use('seaborn')
 
plt.plot(iteration_1, cb_ml, marker='d', linewidth=2, alpha=0.9, label='ML')
plt.plot(iteration_1, cb_ml_rl, marker='v',  linewidth=2, alpha=0.9, label='ML+RL(r)')
plt.plot(iteration_1, cb_rl_r, marker='s', linewidth=2, alpha=0.9, label='RL(r)')
plt.plot(iteration_2, cb_rl_b, marker='.', linewidth=2, alpha=0.9, label='RL(b)')

plt.legend(ncol=4,loc='lower left')
plt.title("Plot of Validation BERTScore for CNN/DailyMail Dataset")
plt.xlabel("Training Iterations")
plt.ylabel("BERTScore")
plt.show()

# %% [markdown]
# #### cnn bertscore vs rouge

# %%
plt.figure(figsize=(8,6))
plt.style.use('seaborn')
 
plt.scatter(cr_ml, cb_ml, marker='d', linewidth=2, alpha=0.9, label='ML')
plt.scatter(cr_ml_rl[1:], cb_ml_rl[1:], marker='v',  linewidth=2, alpha=0.9, label='ML+RL(r)')
plt.scatter(cr_rl_r[1:], cb_rl_r[1:], marker='s', linewidth=2, alpha=0.9, label='RL(r)')
plt.scatter(cr_rl_b[1:], cb_rl_b[1:], marker='.', linewidth=2, alpha=0.9, label='RL(b)')

plt.legend(ncol=4,loc='lower left')
plt.title("Plot of BERTScore against Rouge-L for CNN/DailyMail Dataset")
plt.xlabel("Rouge-L")
plt.ylabel("BERTScore")
plt.show()

# %% [markdown]
# #### wikihow rouge

# %%
wr_iteration_1 = np.arange(10000,16200,200)
wr_ml = np.array([0.2450,0.2664,0.2766,0.2734,0.2645,0.2401,0.2415,0.2805,0.2782,0.2474,0.2652,0.2730,0.2600,0.2647,0.2656,0.2670,0.2701,0.2880,0.2563,0.2737,0.2794,0.2794,0.2617,0.2776,0.2879,0.2860,0.2709,0.2624,0.2705,0.2661,0.2782])

wr_iteration_2 = np.append(np.arange(10000,11000,500),np.arange(10600,16200,200))
wr_ml_rl = np.array([0.2450,0.2621,0.2678,0.2618,0.2662,0.2753,0.2687,0.2754,0.2766,0.2824,0.2730,0.2656,0.2699,0.2772,0.2670,0.2728,0.2709,0.2749,0.2710,0.2761,0.2810,0.2738,0.2790,0.2787,0.2792,0.2825,0.2854,0.2743,0.2699,0.2703])


wr_iteration_3 = np.arange(10000,16200,200)
wr_rl_r = np.array([0.2450,0.3021,0.3100,0.3157,0.3142,0.3094,0.3109,0.3114,0.3152,0.3228,0.3179,0.3133,0.3141,0.3039,0.3028,0.3098,0.3033,0.3104,0.3069,0.3026,0.3017,0.3102,0.3130,0.3100,0.3037,0.3090,0.3115,0.3079,0.3027,0.3107,0.3262])  

wr_iteration_4 = np.arange(10000,15200,100)
wr_rl_b =  np.array([0.2450,0.2709,0.2747,0.2756,0.2695,0.2711,0.2720,0.2713,0.2668,0.2638,0.2592,0.2577,0.2609,0.2598,0.2601,0.2607,0.2613,0.2569,0.2519,0.2519,0.2536,0.2500,0.2497,0.2484,0.2489,0.2526,0.2485,0.2477,0.2462,0.2478,0.2454,0.2483,0.2461,0.2446,0.2447,0.2442,0.2428,0.2417,0.2434,0.2414,0.2446,0.2454,0.2482,0.2455,0.2476,0.2491,0.2498,0.2495,0.2487,0.2484,0.2489,0.2491])


plt.figure(figsize=(8,6))
plt.style.use('seaborn')
 
plt.plot(wr_iteration_1, wr_ml, marker='d', linewidth=2, alpha=0.9, label='ML')
plt.plot(wr_iteration_2, wr_ml_rl, marker='v',  linewidth=2, alpha=0.9, label='ML+RL(r)')
plt.plot(wr_iteration_3, wr_rl_r, marker='s', linewidth=2, alpha=0.9, label='RL(r)')
plt.plot(wr_iteration_4, wr_rl_b, marker='.', linewidth=2, alpha=0.9, label='RL(b)')

plt.legend(ncol=4,loc='lower right')
plt.title("Plot of Validation Rouge-L Score for Wikihow Dataset")
plt.xlabel("Training Iterations")
plt.ylabel("Rouge-L")
plt.show()

# %% [markdown]
# #### wikihow bertscore

# %%
wb_iteration_1 = np.arange(10000,20200,200)
wb_ml = np.array([0.8653669357299805,0.8867985010147095,0.8849369883537292,0.8914600610733032,0.8798505663871765,0.8733870387077332,0.867188036441803,0.8887806534767151,0.8793219923973083,0.8706750869750977,0.8776529431343079,0.8821314573287964,0.8807674646377563,0.8813579678535461,0.8755669593811035,0.8825152516365051,0.8816799521446228,0.8829296231269836,0.8798960447311401,0.8778716325759888,0.8812627196311951,0.8806312084197998,0.8778173923492432,0.8887887001037598,0.8876591920852661,0.8858792781829834,0.8861621618270874,0.8828774094581604,0.8845580220222473,0.8807746767997742,0.8858900666236877,0.8748922944068909,0.88963782787323,0.8802306056022644,0.8895068764686584,0.8859220147132874,0.8826466798782349,0.8870986700057983,0.8846772909164429,0.8727874755859375,0.8823157548904419,0.8770177364349365,0.8787150382995605,0.8847239017486572,0.8754158616065979,0.884371817111969,0.8908545970916748,0.8734208345413208,0.8890321850776672,0.8781612515449524,0.8802916407585144])

wb_iteration_2 = np.append(np.arange(10000,11000,500),np.arange(10600,16200,200))
wb_ml_rl = np.array([0.8653669357299805,0.8720040917396545,0.8730075359344482,0.8723753690719604,0.8745008707046509,0.8762686252593994,0.8736469745635986,0.8760464191436768,0.8756616115570068,0.8810733556747437,0.8768759965896606,0.8763095140457153,0.8733794093132019,0.8796890377998352,0.8733342289924622,0.8759967684745789,0.8775274157524109,0.8789235353469849,0.8772646188735962,0.876751184463501,0.8783829808235168,0.8782716989517212,0.8768958449363708,0.8786001205444336,0.8758171200752258,0.8798243403434753,0.8810360431671143,0.875653862953186,0.8762295246124268,0.8733234405517578])


wb_iteration_3 = np.append(np.arange(10000,10200,200),np.arange(10400,16200,200))
wb_rl_r = np.array([0.8653669357299805,0.894145667552948,0.8963606953620911,0.893333375453949,0.8914797902107239,0.8849109411239624,0.8856309652328491,0.884159505367279,0.8870136737823486,0.885572075843811,0.8829970359802246,0.8848840594291687,0.8753311038017273,0.8752766847610474,0.8711796998977661,0.860256016254425,0.8647223114967346,0.865389347076416,0.8622854948043823,0.8690065741539001,0.8716298341751099,0.8741652965545654,0.8676385283470154,0.8592013120651245,0.8565548658370972,0.8608132004737854,0.8462668657302856,0.8408236503601074,0.8482798337936401,0.8577858209609985])  

wb_iteration_4 = np.append(np.arange(10000,13800,100),np.arange(14200,15200,100))
wb_rl_b =  np.array([0.8653669357299805,0.8869308829307556,0.8884233236312866,0.8925595283508301,0.8883528709411621,0.8925164937973022,0.8965896964073181,0.8920637965202332,0.889481246471405,0.887177586555481,0.8894730806350708,0.8950015902519226,0.8910015225410461,0.8920835256576538,0.8961911797523499,0.8966408371925354,0.8862581849098206,0.8934581279754639,0.9002430438995361,0.900967001914978,0.8934592604637146,0.8958470821380615,0.8985733389854431,0.9012059569358826,0.8989163041114807,0.8964516520500183,0.9019685387611389,0.9006752967834473,0.9014372229576111,0.8975058794021606,0.902228832244873,0.9018149375915527,0.9002111554145813,0.9032031297683716,0.9031404852867126,0.903071939945221,0.9023826122283936,0.90102618932724,0.9033710956573486,0.9035415053367615,0.9032751321792603,0.9025840163230896,0.9021614789962769,0.9027620553970337,0.9026376008987427,0.9033031463623047,0.9037072062492371,0.9026548862457275])

plt.figure(figsize=(8,6))
plt.style.use('seaborn')
 
plt.plot(wb_iteration_1, wb_ml, marker='d', linewidth=2, alpha=0.9, label='ML')
plt.plot(wb_iteration_2, wb_ml_rl, marker='v',  linewidth=2, alpha=0.9, label='ML+RL(r)')
plt.plot(wb_iteration_3, wb_rl_r, marker='s', linewidth=2, alpha=0.9, label='RL(r)')
plt.plot(wb_iteration_4, wb_rl_b, marker='.', linewidth=2, alpha=0.9, label='RL(b)')

plt.legend(ncol=4,loc='lower left')
plt.title("Plot of Validation BERTScore for Wikihow Dataset")
plt.xlabel("Training Iterations")
plt.ylabel("BERTScore")
plt.show()

# %% [markdown]
# #### wikihow rouge vs bertscore

# %%
r_ml = [wr_ml[j] for j in [i for i, e in enumerate(wr_iteration_1) if e in wb_iteration_1]]
b_ml = [wb_ml[j] for j in [i for i, e in enumerate(wb_iteration_1) if e in wr_iteration_1]]

r_ml_rl = [wr_ml_rl[j] for j in [i for i, e in enumerate(wr_iteration_2) if e in wb_iteration_2]]
b_ml_rl = [wb_ml_rl[j] for j in [i for i, e in enumerate(wb_iteration_2) if e in wr_iteration_2]]

r_rl_r = [wr_rl_r[j] for j in [i for i, e in enumerate(wr_iteration_3) if e in wb_iteration_3]]
b_rl_r = [wb_rl_r[j] for j in [i for i, e in enumerate(wb_iteration_3) if e in wr_iteration_3]]

r_rl_b = [wr_rl_b[j] for j in [i for i, e in enumerate(wr_iteration_4) if e in wb_iteration_4]]
b_rl_b = [wb_rl_b[j] for j in [i for i, e in enumerate(wb_iteration_4) if e in wr_iteration_4]]

# %%
plt.figure(figsize=(8,6))
plt.style.use('seaborn')
 
plt.scatter(r_ml, b_ml, marker='d', linewidth=2, alpha=0.9, label='ML')
plt.scatter(r_ml_rl[1:], b_ml_rl[1:], marker='v',  linewidth=2, alpha=0.9, label='ML+RL(r)')
plt.scatter(r_rl_r[1:], b_rl_r[1:], marker='s', linewidth=2, alpha=0.9, label='RL(r)')
plt.scatter(r_rl_b[1:], b_rl_b[1:], marker='.', linewidth=2, alpha=0.9, label='RL(b)')

plt.legend(ncol=4,loc='lower left')
plt.title("Plot of BERTScore against Rouge-L for Wikihow Dataset")
plt.xlabel("Rouge-L")
plt.ylabel("BERTScore")
plt.show()
